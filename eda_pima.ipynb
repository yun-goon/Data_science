# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv("data/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df_null = df.isnull()
df_null.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False

# %%
df_null.sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
feature_columns=df.columns[0:-1].tolist() #  Series 객체의 값을 Python의 리스트로 변환하는 메서드
feature_columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
cols = feature_columns[1:]
cols
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
df_null = df[cols].replace(0, np.nan)
df_null = df_null.isnull()
df_null.sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
df_null.sum().plot.barh() #plot.barh(): 수평 막대 그래프
# Out:
# <Axes: >

# %%
df_null.mean() * 100
# Out:
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %%
plt.figure(figsize=(15, 4))
sns.heatmap(df_null, cmap="Greys_r")
# Out:
# <Axes: >

# %%
df["Outcome"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df["Outcome"].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
df.groupby(["Pregnancies"])["Outcome"].mean() # "Pregnancies" 열을 기준으로 그룹화하여 각 그룹 내에서 "Outcome" 열의 평균을 계산하는 작업을 수행
# Out:
# Pregnancies
# 0     0.342342
# 1     0.214815
# 2     0.184466
# 3     0.360000
# 4     0.338235
# 5     0.368421
# 6     0.320000
# 7     0.555556
# 8     0.578947
# 9     0.642857
# 10    0.416667
# 11    0.636364
# 12    0.444444
# 13    0.500000
# 14    1.000000
# 15    1.000000
# 17    1.000000
# Name: Outcome, dtype: float64

# %%
df.groupby(["Pregnancies"])["Outcome"].agg(["mean", "count"]) #DataFrame에서 "Pregnancies" 열을 기준으로 그룹화하고, 각 그룹 내에서 "Outcome" 열에 대해 평균과 해당 그룹의 데이터 개수(count)를 동시에 계산
# Out:
#                  mean  count
# Pregnancies
# 0            0.342342    111
# 1            0.214815    135
# 2            0.184466    103
# 3            0.360000     75
# 4            0.338235     68
# 5            0.368421     57
# 6            0.320000     50
# 7            0.555556     45
# 8            0.578947     38
# 9            0.642857     28
# 10           0.416667     24
# 11           0.636364     11
# 12           0.444444      9
# 13           0.500000     10
# 14           1.000000      2
# 15           1.000000      1
# 17           1.000000      1

# %%
df_po = df.groupby(["Pregnancies"])["Outcome"].agg(["mean", "count"]).reset_index()
df_po
# Out:
#     Pregnancies      mean  count
# 0             0  0.342342    111
# 1             1  0.214815    135
# 2             2  0.184466    103
# 3             3  0.360000     75
# 4             4  0.338235     68
# 5             5  0.368421     57
# 6             6  0.320000     50
# 7             7  0.555556     45
# 8             8  0.578947     38
# 9             9  0.642857     28
# 10           10  0.416667     24
# 11           11  0.636364     11
# 12           12  0.444444      9
# 13           13  0.500000     10
# 14           14  1.000000      2
# 15           15  1.000000      1
# 16           17  1.000000      1

# %%
df_po.plot()
# Out:
# <Axes: >

# %%
df_po["mean"].plot()
# Out:
# <Axes: >

# %%
df_po["mean"].plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(data=df, x="Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(data=df, x="Pregnancies")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
sns.countplot(data=df, x="Pregnancies", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
df["Pregnancies_high"] = df["Pregnancies"] > 6
df[["Pregnancies", "Pregnancies_high"]].head()
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %%
sns.countplot(data=df, x="Pregnancies_high")
# Out:
# <Axes: xlabel='Pregnancies_high', ylabel='count'>

# %%
sns.countplot(data=df, x="Pregnancies_high", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies_high', ylabel='count'>

# %%
sns.barplot(data=df, x="Outcome", y="BMI")
# Out:
# <Axes: xlabel='Outcome', ylabel='BMI'>

# %%
sns.barplot(data=df, x="Outcome", y="Glucose")
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.barplot(data=df, x="Outcome", y="Insulin")
# Out:
# <Axes: xlabel='Outcome', ylabel='Insulin'>

# %%
sns.barplot(data=df, x="Pregnancies", y="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Outcome'>

# %%
sns.barplot(data=df, x="Pregnancies", y="Glucose", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.barplot(data=df, x="Pregnancies", y="BMI", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BMI'>

# %%
sns.barplot(data=df, x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
sns.barplot(data=df[df["Insulin"] > 0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
sns.boxplot(data=df, x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
sns.boxplot(data=df[df["Insulin"] > 0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(data=df[df["Insulin"] > 0], x="Pregnancies", y="Insulin", hue="Outcome", split=True)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>

# %%
plt.figure(figsize=(15, 4))
sns.swarmplot(data=df[df["Insulin"] > 0], x="Pregnancies", y="Insulin", hue="Outcome")
# 산포도
# Out:
# c:\Users\edwar\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\edwar\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 26.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\edwar\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Pregnancies', ylabel='Insulin'>
# c:\Users\edwar\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# displot은 1개의 수치형 변수를 표현할 때 사용하는 시각화 그래프입니다.
#
# countplot은 카테고리형 데이터를 시각화할 때 사용합니다.
#
# distplot은 다른 그래프와 달리 data 옵션 없이 바로 Series 데이터를 넣어줍니다.

# %%
sns.distplot(df["Pregnancies"])
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\4004874791.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Pregnancies"])
# <Axes: xlabel='Pregnancies', ylabel='Density'>

# %%
df_0 = df[df["Outcome"] == 0]
df_1 = df[df["Outcome"] == 1]
df_0.shape, df_1.shape
# Out:
# ((500, 10), (268, 10))

# %%
sns.distplot(df_0["Pregnancies"])
sns.distplot(df_1["Pregnancies"])
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2685521112.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_0["Pregnancies"])
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2685521112.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1["Pregnancies"])
# <Axes: xlabel='Pregnancies', ylabel='Density'>

# %%
sns.distplot(df_0["Age"])
sns.distplot(df_1["Age"])
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\1766021489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_0["Age"])
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\1766021489.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df_0["Age"], hist=False)
sns.distplot(df_1["Age"], hist=False)
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\1389550997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_0["Age"], hist=False)
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\1389550997.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1["Age"], hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df_0["Age"], hist=False, rug=True)
sns.distplot(df_1["Age"], hist=False, rug=True)
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2209682344.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_0["Age"], hist=False, rug=True)
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2209682344.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1["Age"], hist=False, rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df_0["Age"], hist=False, rug=True, label=0)
sns.distplot(df_1["Age"], hist=False, rug=True, label=1)
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2859723022.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_0["Age"], hist=False, rug=True, label=0)
# C:\Users\edwar\AppData\Local\Temp\ipykernel_20908\2859723022.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1["Age"], hist=False, rug=True, label=1)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.figure(1,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plt.figure(1,4)
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib\pyplot.py:840, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     830 if len(allnums) == max_open_warning >= 1:
#     831     _api.warn_external(
#     832         f"More than {max_open_warning} figures have been opened. "
#     833         f"Figures created through the pyplot interface "
#    (...)
#     837         f"Consider using `matplotlib.pyplot.close()`.",
#     838         RuntimeWarning)
# --> 840 manager = new_figure_manager(
#     841     num, figsize=figsize, dpi=dpi,
#     842     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     843     FigureClass=FigureClass, **kwargs)
#     844 fig = manager.canvas.figure
#     845 if fig_label:
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib\pyplot.py:384, in new_figure_manager(*args, **kwargs)
#     382 """Create a new figure manager instance."""
#     383 _warn_if_gui_out_of_main_thread()
# --> 384 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File c:\Users\edwar\anaconda3\Lib\site-packages\matplotlib\figure.py:2536, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2533 if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
#    2534     raise ValueError('figure size must be positive finite not '
#    2535                      f'{figsize}')
# -> 2536 self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#    2538 self.dpi_scale_trans = Affine2D().scale(dpi)
#    2539 # do not use property as it will trigger
#
# TypeError: Value after * must be an iterable, not int
